# %% [markdown]
# ## Get Taxi Data, Web Scraping

# %%
# Web scraping, get taxi data for a definite taxi ride or for a day
# https://data.cityofchicago.org/Transportation/Taxi-Trips-2024-/ajtu-isnz/about_data

# %%
# Module to send HTTP requests (like GET, POST, etc.) to fetch web pages or APIs
import requests

# %%
# Set url to the API of the City of Chicago's open data portal, and it’s
# querying a dataset using a specific trip_id. Sending GET request and
# parsing JSON response into a Python list of dictionaries
url = "https://data.cityofchicago.org/resource/ajtu-isnz.json?trip_id=000001dd3888f74eaf131b0627d367e8c5b73cc4"
response = requests.get(url)
data = response.json()
data
# Out:
# [{'trip_id': '000001dd3888f74eaf131b0627d367e8c5b73cc4',
#   'taxi_id': 'd5fc0adc436b269c2ce07e37eff1af604a963c8538536bd6be39f0b399c0a6b14bafdaca01d34d939738ae4df46ddbeaf7b83aeb4506199bb645112e791e07e9',
#   'trip_start_timestamp': '2024-02-26T14:30:00.000',
#   'trip_end_timestamp': '2024-02-26T15:15:00.000',
#   'trip_seconds': '2640',
#   'trip_miles': '16.3',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '5',
#   'fare': '42.75',
#   'tips': '12.05',
#   'tolls': '0',
#   'extras': '5',
#   'trip_total': '59.8',
#   'payment_type': 'Credit Card',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]},
#   'dropoff_centroid_latitude': '41.947791586',
#   'dropoff_centroid_longitude': '-87.683834942',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6838349425, 41.9477915865]}}]

# %%
# GET Request and parse JSON from URL with filters.
# $where clause to filter trips that started on October 31, 2024, between
# 00:00:00 and 23:59:59. $limit=30000 to return up to 30,000 records (because
# APIs often limit results unless you ask for more).
url = (
    f"https://data.cityofchicago.org/resource/ajtu-isnz.json?"
    f"$where=trip_start_timestamp >= '2024-10-31T00:00:00' "
    f"AND trip_start_timestamp <= '2024-10-31T23:59:59'&$limit=30000"
)
response = requests.get(url)
data = response.json()

len(data)
# Out:
# 17992

# %%
# requests - used to send HTTP requests to get data from an API.
# datetime - handles date and time.
# relativedelta - allows more flexible date manipulations
#                 (e.g., subtracting months).
import requests
from datetime import datetime
from dateutil.relativedelta import relativedelta

# Calculate date two months ago and format the resulting date to a string
# like '2025-02-20'
current_datetime = datetime.now() - relativedelta(months=2)
formatted_datetime = current_datetime.strftime("%Y-%m-%d")

# Build API URL, send request and parse response
url = (
    f"https://data.cityofchicago.org/resource/ajtu-isnz.json?"
    f"$where=trip_start_timestamp >= '{formatted_datetime}T00:00:00' "
    f"AND trip_start_timestamp <= '{formatted_datetime}T23:59:59'&$limit=30000"
)
response = requests.get(url)
data = response.json()

# %%
# Display result
data
# Out:
# [{'trip_id': '4e39f4210373d96df0c2792554f2f4b483a46f39',
#   'taxi_id': '477e2191cd2213e2db9413d810936b2f24a73c8e5270594c724f811dbe4cfea5b58519d789ac8fb30d3ac6ee375721019e2e793a889be528f59327e0cc32ea94',
#   'trip_start_timestamp': '2025-02-23T23:45:00.000',
#   'trip_end_timestamp': '2025-02-24T00:00:00.000',
#   'trip_seconds': '830',
#   'trip_miles': '0',
#   'dropoff_community_area': '33',
#   'fare': '13.25',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '15.75',
#   'payment_type': 'Cash',
#   'company': 'Tac - Yellow Cab Association',
#   'dropoff_centroid_latitude': '41.857183858',
#   'dropoff_centroid_longitude': '-87.620334624',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6203346241, 41.8571838585]}},
#  {'trip_id': '51d44b4e2e3cf13652298f7266c8420ac753e0c0',
#   'taxi_id': 'd4e172502a18df80190c19176a06c0d9344f71abdbe521e964ad99caae1c73860f3f1f7cc96e1dcac410fbe9aba385af639ef03c028b0453429bbfb67e78010b',
#   'trip_start_timestamp': '2025-02-23T23:45:00.000',
#   'trip_end_timestamp': '2025-02-24T00:00:00.000',
#   'trip_seconds': '682',
#   'trip_miles': '4.61',
#   'pickup_community_area': '8',
#   'dropoff_community_area': '6',
#   'fare': '17.17',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '17.67',
#   'payment_type': 'Mobile',
#   'company': 'Globe Taxi',
#   'pickup_centroid_latitude': '41.899602111',
#   'pickup_centroid_longitude': '-87.633308037',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]},
#   'dropoff_centroid_latitude': '41.944226601',
#   'dropoff_centroid_longitude': '-87.655998182',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6559981815, 41.9442266014]}},
#  {'trip_id': '53cc0af124ad042946755076c289a0bb0b416e0f',
#   'taxi_id': '0d3fc37b4e76ff16045a1e82cd817625cebff2683927eb6244b87a974e85f84d17e3ab3d727c92918309df38465d0ca9624f1d1bff5dfba4849125a677a6f05d',
#   'trip_start_timestamp': '2025-02-23T23:45:00.000',
#   'trip_end_timestamp': '2025-02-24T00:00:00.000',
#   'trip_seconds': '1285',
#   'trip_miles': '13.42',
#   'pickup_community_area': '56',
#   'dropoff_community_area': '39',
#   'fare': '34',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '38',
#   'payment_type': 'Cash',
#   'company': 'Taxicab Insurance Agency Llc',
#   'pickup_centroid_latitude': '41.79259236',
#   'pickup_centroid_longitude': '-87.769615453',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.7696154528, 41.7925923603]},
#   'dropoff_centroid_latitude': '41.808916283',
#   'dropoff_centroid_longitude': '-87.596183344',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.5961833442, 41.8089162826]}},
#  {'trip_id': '54c132ce98fd0dbdd522b518ab1022f59d0d2036',
#   'taxi_id': '61d83eb1d34ccd8dac5bdd962bc13e2ac077b0c7ecbf1d0da9b3153b3c01a3d2cc602501919974096100cf70f1621caaf3f8c2510c45748d78c279b67d9bf0cf',
#   'trip_start_timestamp': '2025-02-23T23:45:00.000',
#   'trip_end_timestamp': '2025-02-24T00:00:00.000',
#   'trip_seconds': '1080',
#   'trip_miles': '14.5',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '24',
#   'fare': '52.75',
#   'tips': '8',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '65.25',
#   'payment_type': 'Credit Card',
#   'company': 'Globe Taxi',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]},
#   'dropoff_centroid_latitude': '41.901206994',
#   'dropoff_centroid_longitude': '-87.676355989',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6763559892, 41.9012069941]}},
#  {'trip_id': '54c8e813447ccac84f1b1c526d782f3f045ae216',
#   'taxi_id': '455b6b5cae6ca5a17cddd251485f2266d13d6a2c92f07c2968c24f39032ecc76fcc1928d14ce8bba5214e04fe22bdcaa431471b0fbabbdf8fa62650c164e901a',
#   'trip_start_timestamp': '2025-02-23T23:45:00.000',
#   'trip_end_timestamp': '2025-02-24T00:00:00.000',
#   'trip_seconds': '1052',
#   'trip_miles': '15.53',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '7',
#   'fare': '38.75',
#   'tips': '8.85',
#   'tolls': '0',
#   'extras': '5',
#   'trip_total': '53.1',
#   'payment_type': 'Credit Card',
#   'company': 'Sun Taxi',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]},
#   'dropoff_centroid_latitude': '41.922686284',
#   'dropoff_centroid_longitude': '-87.649488729',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6494887289, 41.9226862843]}},
#  {'trip_id': '560d7c2324cd34298f7f329101fdb79431d1d9cb',
#   'taxi_id': 'bedb270bce40664555c0e645a3f6c242d8f64ed541f6f56b1ecfd2d03ef229fb32cce2312110d6cb17459770dd6d9f6acbb6ca70f999ff852f59d348c3e52681',
#   'trip_start_timestamp': '2025-02-23T23:45:00.000',
#   'trip_end_timestamp': '2025-02-24T00:15:00.000',
#   'trip_seconds': '1153',
#   'trip_miles': '12.47',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '5',
#   'fare': '32.25',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '6',
#   'trip_total': '38.25',
#   'payment_type': 'Cash',
#   'company': 'Blue Ribbon Taxi Association',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]},
#   'dropoff_centroid_latitude': '41.947791586',
#   'dropoff_centroid_longitude': '-87.683834942',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6838349425, 41.9477915865]}},
#  {'trip_id': '572e036703767749de8df5556cb8b4b6b43c5e75',
#   'taxi_id': 'fbfc2ff558d0fc2dd96362ef65d25e08f00b13bc427645692cc034fb62d0ccf5f19c7187554fdf79c714323023b793de64da10de48051c38528f05ca5fc29e27',
#   'trip_start_timestamp': '2025-02-23T23:45:00.000',
#   'trip_end_timestamp': '2025-02-24T01:00:00.000',
#   'trip_seconds': '4080',
#   'trip_miles': '11.5',
#   'pickup_community_area': '28',
#   'dropoff_community_area': '28',
#   'fare': '41',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '41',
#   'payment_type': 'Cash',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.874005383',
#   'pickup_centroid_longitude': '-87.66351755',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6635175498, 41.874005383]},
#   'dropoff_centroid_latitude': '41.874005383',
#   'dropoff_centroid_longitude': '-87.66351755',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6635175498, 41.874005383]}},
#  {'trip_id': '604ed955c083ec7bd6a4e074e3c9de54ebe7e7d9',
#   'taxi_id': '3f6562a2a18861cf21a21101c14cc91dd7c4d72cdce80f3252c67c3ddf96b1a2546c01536f3c9adc5c13fa75b274398ca154d7a4bdc41fc99f768d8801f6bdfe',
#   'trip_start_timestamp': '2025-02-23T23:45:00.000',
#   'trip_end_timestamp': '2025-02-23T23:45:00.000',
#   'trip_seconds': '7',
#   'trip_miles': '0',
#   'pickup_community_area': '8',
#   'dropoff_community_area': '8',
#   'fare': '55',
#   'tips': '11.1',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '66.6',
#   'payment_type': 'Credit Card',
#   'company': 'Chicago Independents',
#   'pickup_centroid_latitude': '41.899602111',
#   'pickup_centroid_longitude': '-87.633308037',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]},
#   'dropoff_centroid_latitude': '41.899602111',
#   'dropoff_centroid_longitude': '-87.633308037',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]}},
#  {'trip_id': '6581044c6d91849f4f592bffc223410aa7388af1',
#   'taxi_id': '3c5b4f29aac78c145bf09a567d547e22ab95655e4288d93bb78ac65c87a6843c6cc87c02dadd0a8652f43c3206f416b11dd7e03bb438be1c5a176902f1afb742',
#   'trip_start_timestamp': '2025-02-23T23:45:00.000',
#   'trip_end_timestamp': '2025-02-24T00:00:00.000',
#   'trip_seconds': '1201',
#   'trip_miles': '18.81',
#   'pickup_census_tract': '17031980000',
#   'dropoff_census_tract': '17031839100',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '32',
#   'fare': '45.5',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '49.5',
#   'payment_type': 'Cash',
#   'company': 'Sun Taxi',
#   'pickup_centroid_latitude': '41.97907082',
#   'pickup_centroid_longitude': '-87.903039661',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.9030396611, 41.9790708201]},
#   'dropoff_centroid_latitude': '41.880994471',
#   'dropoff_centroid_longitude': '-87.632746489',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6327464887, 41.8809944707]}},
#  {'trip_id': '6d00bc863313f13cc28688f1ad68333c0e9977de',
#   'taxi_id': '9a423881d4046f5590943c08ec5e58d59f5ebd91fe26aa9ef49ad0dfe587e3d3a78dc5e2d214e4d42120e5296ebadeb100494177de8b0fc8ef6a1b3e5290669b',
#   'trip_start_timestamp': '2025-02-23T23:45:00.000',
#   'trip_end_timestamp': '2025-02-24T00:00:00.000',
#   'trip_seconds': '1320',
#   'trip_miles': '18.1',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '8',
#   'fare': '44.25',
#   'tips': '13.15',
#   'tolls': '0',
#   'extras': '8',
#   'trip_total': '65.4',
#   'payment_type': 'Credit Card',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]},
#   'dropoff_centroid_latitude': '41.899602111',
#   'dropoff_centroid_longitude': '-87.633308037',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]}},
#  {'trip_id': '7162196cf1d10c72b070ee9773030a0cbd538625',
#   'taxi_id': 'c7a0a182e884af18d25c22584df83f14df5b044b900930885d55b2a2a5c0ddb23d2d3eadbb652b2e15b4167609d461a8af488b075a458d2ed19647feac570602',
#   'trip_start_timestamp': '2025-02-23T23:45:00.000',
#   'trip_end_timestamp': '2025-02-23T23:45:00.000',
#   'trip_seconds': '5',
#   'trip_miles': '0',
#   'pickup_community_area': '24',
#   'dropoff_community_area': '24',
#   'fare': '42.75',
#   'tips': '8.65',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '51.9',
#   'payment_type': 'Credit Card',
#   'company': 'Flash Cab',
#   'pickup_centroid_latitude': '41.901206994',
#   'pickup_centroid_longitude': '-87.676355989',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6763559892, 41.9012069941]},
#   'dropoff_centroid_latitude': '41.901206994',
#   'dropoff_centroid_longitude': '-87.676355989',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6763559892, 41.9012069941]}},
#  {'trip_id': '74b815057cb8fd39e13d338a13bae7884fce5673',
#   'taxi_id': 'f9448164dcb56f4f31c2b2ad562f31443a01885c2bda20d6325a0747c9857007a024d358c98ed634fba5791a9dcbaf7252302b7dad34fa6bea7e625d2d185d4e',
#   'trip_start_timestamp': '2025-02-23T23:45:00.000',
#   'trip_end_timestamp': '2025-02-24T00:00:00.000',
#   'trip_seconds': '731',
#   'trip_miles': '5.43',
#   'pickup_community_area': '56',
#   'fare': '15.5',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '19.5',
#   'payment_type': 'Cash',
#   'company': 'Patriot Taxi Dba Peace Taxi Associat',
#   'pickup_centroid_latitude': '41.79259236',
#   'pickup_centroid_longitude': '-87.769615453',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.7696154528, 41.7925923603]}},
#  {'trip_id': '7831896c4ad19a7b00528c6218355a47616b7056',
#   'taxi_id': 'a548c63608ec50e02a2311a0b6b1b2274995e3637ccb4ca7c3510c44756b5b0378906335f1e30563615c9ec8efd0f81ef97199ad869a68670f4d0eb85725ceaa',
#   'trip_start_timestamp': '2025-02-23T23:45:00.000',
#   'trip_end_timestamp': '2025-02-24T00:15:00.000',
#   'trip_seconds': '1413',
#   'trip_miles': '16.78',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '8',
#   'fare': '42',
#   'tips': '9.3',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '55.8',
#   'payment_type': 'Credit Card',
#   'company': 'City Service',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]},
#   'dropoff_centroid_latitude': '41.899602111',
#   'dropoff_centroid_longitude': '-87.633308037',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]}},
#  {'trip_id': '7f2b50caff5e1c5e36f2ee633588aedf133181b6',
#   'taxi_id': '60ee73db6313892e9fb80150895f1036b4a82eca1b886922164d2be9c2a5c3df288c1dd2717024983cb9080a847944fcd983422d4422d62f8984664b5f59941f',
#   'trip_start_timestamp': '2025-02-23T23:45:00.000',
#   'trip_end_timestamp': '2025-02-23T23:45:00.000',
#   'trip_seconds': '450',
#   'trip_miles': '0',
#   'pickup_community_area': '32',
#   'dropoff_community_area': '28',
#   'fare': '3.25',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '57',
#   'trip_total': '60.25',
#   'payment_type': 'Cash',
#   'company': 'Globe Taxi',
#   'pickup_centroid_latitude': '41.878865584',
#   'pickup_centroid_longitude': '-87.625192142',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6251921424, 41.8788655841]},
#   'dropoff_centroid_latitude': '41.874005383',
#   'dropoff_centroid_longitude': '-87.66351755',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6635175498, 41.874005383]}},
#  {'trip_id': '8029638afe78e8e2a7abb95006599e5d62b323cf',
#   'taxi_id': 'eead1e2c21b26570411277cb384d3d8d072fc6da913b0617c841cfd3f6cdf40c508395c589a56d12afd2ec4002948fdeb56cb029227274b760200d7c0e2dcb1c',
#   'trip_start_timestamp': '2025-02-23T23:45:00.000',
#   'trip_end_timestamp': '2025-02-24T00:15:00.000',
#   'trip_seconds': '1184',
#   'trip_miles': '10.25',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '12',
#   'fare': '27',
#   'tips': '4.72',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '36.22',
#   'payment_type': 'Credit Card',
#   'company': '5 Star Taxi',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]},
#   'dropoff_centroid_latitude': '41.993930128',
#   'dropoff_centroid_longitude': '-87.758353588',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.7583535876, 41.9939301285]}},
#  {'trip_id': '81481dff5935cc1f5c70eec2ece09f61a365e416',
#   'taxi_id': 'f760c301740afe577d6c0e2f6de2cfecccf6ede158b8a3825331005da37a008716599169f4b467bc8b88e65318b5008499ad0ea4e05a7465c6bce4a1d5e70350',
#   'trip_start_timestamp': '2025-02-23T23:45:00.000',
#   'trip_end_timestamp': '2025-02-24T00:15:00.000',
#   'trip_seconds': '2257',
#   'trip_miles': '8.31',
#   'pickup_community_area': '13',
#   'dropoff_community_area': '8',
#   'fare': '24.75',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '24.75',
#   'payment_type': 'Prcard',
#   'company': 'Sun Taxi',
#   'pickup_centroid_latitude': '41.983636307',
#   'pickup_centroid_longitude': '-87.723583185',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.7235831853, 41.9836363072]},
#   'dropoff_centroid_latitude': '41.899602111',
#   'dropoff_centroid_longitude': '-87.633308037',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]}},
#  {'trip_id': '861fcdaf9f56f3436df40bc7c9afdec6e1ab4713',
#   'taxi_id': '0f846a75c6e6a4a065d188e1a4c41eb2f8794a2fc073b1338d79c7c42a6ba625e064022f9d7f71e8cb61a08e371ee7289431ade0dd5f5a6e4b0aae94178f1860',
#   'trip_start_timestamp': '2025-02-23T23:45:00.000',
#   'trip_end_timestamp': '2025-02-23T23:45:00.000',
#   'trip_seconds': '6',
#   'trip_miles': '0',
#   'pickup_community_area': '28',
#   'dropoff_community_area': '28',
#   'fare': '26',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '26',
#   'payment_type': 'Cash',
#   'company': 'Flash Cab',
#   'pickup_centroid_latitude': '41.874005383',
#   'pickup_centroid_longitude': '-87.66351755',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6635175498, 41.874005383]},
#   'dropoff_centroid_latitude': '41.874005383',
#   'dropoff_centroid_longitude': '-87.66351755',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6635175498, 41.874005383]}},
#  {'trip_id': '96ac77e1456360ea34a209848c3dd0706d6566bf',
#   'taxi_id': '799deebf2f513dbebcad07d26fedd03920ea747cb97055dadf972acd72f5b766b75041c294ea096a3ca6bc658dbd79f762c7079a94781c89f756a514f29c9c71',
#   'trip_start_timestamp': '2025-02-23T23:45:00.000',
#   'trip_end_timestamp': '2025-02-24T00:15:00.000',
#   'trip_seconds': '960',
#   'trip_miles': '6.1',
#   'pickup_community_area': '28',
#   'dropoff_community_area': '7',
#   'fare': '18.5',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '18.5',
#   'payment_type': 'Cash',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.874005383',
#   'pickup_centroid_longitude': '-87.66351755',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6635175498, 41.874005383]},
#   'dropoff_centroid_latitude': '41.922686284',
#   'dropoff_centroid_longitude': '-87.649488729',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6494887289, 41.9226862843]}},
#  {'trip_id': '98859d43671decdc8f0614bb1a72c31c74303814',
#   'taxi_id': 'a38f985a8df43cf3ab313692ff9d7d081b9460567035a5a00a45274a7cec70599031ea726e0e587ad6e3ee0c0d257d9886fa37a509218adf5e409b6700d28db3',
#   'trip_start_timestamp': '2025-02-23T23:45:00.000',
#   'trip_end_timestamp': '2025-02-24T00:00:00.000',
#   'trip_seconds': '1622',
#   'trip_miles': '14.55',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '6',
#   'fare': '38',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '42.5',
#   'payment_type': 'Credit Card',
#   'company': 'Medallion Leasin',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]},
#   'dropoff_centroid_latitude': '41.944226601',
#   'dropoff_centroid_longitude': '-87.655998182',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6559981815, 41.9442266014]}},
#  {'trip_id': '98cd940742c1b587923408626bd104481a135d6e',
#   'taxi_id': '5732bb53e9becb096e11b52228bb5079a585622bd15b745b5951f8ae0fa018ac511f3faf0863a9e890c5b8be5a601b6ee2e6301404137fa406855840ef83d45c',
#   'trip_start_timestamp': '2025-02-23T23:45:00.000',
#   'trip_end_timestamp': '2025-02-24T00:15:00.000',
#   'trip_seconds': '1500',
#   'trip_miles': '13.4',
#   'pickup_community_area': '56',
#   'dropoff_community_area': '8',
#   'fare': '34.75',
#   'tips': '5.96',
#   'tolls': '0',
#   'extras': '5',
#   'trip_total': '45.71',
#   'payment_type': 'Credit Card',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.79259236',
#   'pickup_centroid_longitude': '-87.769615453',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.7696154528, 41.7925923603]},
#   'dropoff_centroid_latitude': '41.899602111',
#   'dropoff_centroid_longitude': '-87.633308037',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]}},
#  {'trip_id': '9dfc21460b895a2e62870870dfa89bc936ae664e',
#   'taxi_id': '0845bb9862fb9f090225931bc2492b25dda810ef1312ce2ca419850772cecdf3efbf0341d2685506c67eb04747a6bef507c466e667fccbd1241c5046222cee4c',
#   'trip_start_timestamp': '2025-02-23T23:45:00.000',
#   'trip_end_timestamp': '2025-02-23T23:45:00.000',
#   'trip_seconds': '399',
#   'trip_miles': '2.59',
#   'pickup_community_area': '76',
#   'fare': '9.75',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '13.75',
#   'payment_type': 'Cash',
#   'company': 'Sun Taxi',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]}},
#  {'trip_id': '9eedc8ceafa0e4f74a2db7fbb1f018a6fd376da0',
#   'taxi_id': '70d9077f1ddbc6c93643ef4dbf4a3110b1826f68a69801dd5cf84e637a72c52c11b976a96f745591638a6589580b71049e79c0001878eec684ae1530c7ac8c88',
#   'trip_start_timestamp': '2025-02-23T23:45:00.000',
#   'trip_end_timestamp': '2025-02-23T23:45:00.000',
#   'trip_seconds': '0',
#   'trip_miles': '0',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '76',
#   'fare': '30',
#   'tips': '9.15',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '39.15',
#   'payment_type': 'Credit Card',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]},
#   'dropoff_centroid_latitude': '41.980264315',
#   'dropoff_centroid_longitude': '-87.913624596',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]}},
#  {'trip_id': '9efbc526b9ef45c89f77a71f0a16e98a0d1e0422',
#   'taxi_id': 'a712fead8a31c26ab7948b116a760ac22af166d63d2fc272bdb1ab031df2d1338737144b4571723cda5d05f0cabfc94803fd6911a1b6bd3df9e97847e8bba6f7',
#   'trip_start_timestamp': '2025-02-23T23:45:00.000',
#   'trip_end_timestamp': '2025-02-24T00:15:00.000',
#   'trip_seconds': '1073',
#   'trip_miles': '16.54',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '8',
#   'fare': '40.75',
#   'tips': '11.31',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '56.56',
#   'payment_type': 'Credit Card',
#   'company': 'City Service',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]},
#   'dropoff_centroid_latitude': '41.899602111',
#   'dropoff_centroid_longitude': '-87.633308037',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]}},
#  {'trip_id': 'a3151c8eb441d5c53423d8065e2f26b4323b4b6d',
#   'taxi_id': 'f2dc0cb125f6187de4f432b3c77c12e2e6d07477049dfe77b4d5b5e8c0882df155c52e9c126a38751ac646b7b23fb21fb6a2b6558e0d6d3495a2e3da6d6ef3f5',
#   'trip_start_timestamp': '2025-02-23T23:45:00.000',
#   'trip_end_timestamp': '2025-02-24T00:15:00.000',
#   'trip_seconds': '1239',
#   'trip_miles': '13.14',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '22',
#   'fare': '33.75',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '5',
#   'trip_total': '38.75',
#   'payment_type': 'Cash',
#   'company': 'Taxicab Insurance Agency Llc',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]},
#   'dropoff_centroid_latitude': '41.92276062',
#   'dropoff_centroid_longitude': '-87.699155343',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6991553432, 41.9227606205]}},
#  {'trip_id': 'a39f8643534f6ee570f0f577ab3d777dcdf3f5d4',
#   'taxi_id': 'f451123ff58e8ef1ca5e64de85da57d7cf463c5ee73e6ad1301d57c9ce7a1dc958cd2c34bc424919ca74e3fc9b6ab261bc7923a725a5c3da00f9b3138e5e0c1d',
#   'trip_start_timestamp': '2025-02-23T23:45:00.000',
#   'trip_end_timestamp': '2025-02-24T00:15:00.000',
#   'trip_seconds': '2416',
#   'trip_miles': '21.41',
#   'pickup_community_area': '56',
#   'fare': '52.75',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '28.75',
#   'trip_total': '81.5',
#   'payment_type': 'Cash',
#   'company': 'Blue Ribbon Taxi Association',
#   'pickup_centroid_latitude': '41.79259236',
#   'pickup_centroid_longitude': '-87.769615453',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.7696154528, 41.7925923603]}},
#  {'trip_id': 'a76697914753bf9ca455f986b50ea7c01e53690b',
#   'taxi_id': 'f20c9c5845dab1e51799b959d378c102763d4b31d738da7ea1f7fee763a4c830854cf6025fbe42e7c37dddab03ef2cf43bc775bdd6c5a4114d307dbf415728a5',
#   'trip_start_timestamp': '2025-02-23T23:45:00.000',
#   'trip_end_timestamp': '2025-02-23T23:45:00.000',
#   'trip_seconds': '402',
#   'trip_miles': '1.23',
#   'pickup_community_area': '32',
#   'dropoff_community_area': '32',
#   'fare': '8.5',
#   'tips': '1.15',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '10.15',
#   'payment_type': 'Mobile',
#   'company': 'Flash Cab',
#   'pickup_centroid_latitude': '41.878865584',
#   'pickup_centroid_longitude': '-87.625192142',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6251921424, 41.8788655841]},
#   'dropoff_centroid_latitude': '41.878865584',
#   'dropoff_centroid_longitude': '-87.625192142',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6251921424, 41.8788655841]}},
#  {'trip_id': 'a978796ae3ea827d5ed8a0a849ceabd683c1c3a0',
#   'taxi_id': 'b1651e2b8312db2b3d66b4a1a629d3c5bd4bcc3f3ce0dd83b5572588b00c1b2c79d0c973d0c64dcce826cb6ca4fca069f937d4584a4006bc3e07251e977d8587',
#   'trip_start_timestamp': '2025-02-23T23:45:00.000',
#   'trip_end_timestamp': '2025-02-24T00:00:00.000',
#   'trip_seconds': '1100',
#   'trip_miles': '14.99',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '24',
#   'fare': '37.5',
#   'tips': '8.4',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '50.4',
#   'payment_type': 'Credit Card',
#   'company': 'City Service',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]},
#   'dropoff_centroid_latitude': '41.901206994',
#   'dropoff_centroid_longitude': '-87.676355989',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6763559892, 41.9012069941]}},
#  {'trip_id': 'acaed1ba69444cf259e799714a6c67c11c62ef0e',
#   'taxi_id': '249d932165de24c10140f979fa81b350183cff7ac630991ebc0e2b567883a3c60780ed9dd4f087f74022f6af1eb04d11f888b84b182f90a5e1996bc87da1fa70',
#   'trip_start_timestamp': '2025-02-23T23:45:00.000',
#   'trip_end_timestamp': '2025-02-24T00:00:00.000',
#   'trip_seconds': '1136',
#   'trip_miles': '13.47',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '22',
#   'fare': '34',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '38.5',
#   'payment_type': 'Credit Card',
#   'company': 'Globe Taxi',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]},
#   'dropoff_centroid_latitude': '41.92276062',
#   'dropoff_centroid_longitude': '-87.699155343',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6991553432, 41.9227606205]}},
#  {'trip_id': 'ad2d02d556c587b1bbd18f24e50bf5cbad2bd8b8',
#   'taxi_id': '8dbaf4164524af926ddeab5dd084183e585f4cb8cc47febbd2839986312079990fae419bfaa5d557574992d87939d1842f1c86812c8678bb3806af6fe227d755',
#   'trip_start_timestamp': '2025-02-23T23:45:00.000',
#   'trip_end_timestamp': '2025-02-24T00:00:00.000',
#   'trip_seconds': '967',
#   'trip_miles': '14.01',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '24',
#   'fare': '35',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '39',
#   'payment_type': 'Cash',
#   'company': 'Medallion Leasin',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]},
#   'dropoff_centroid_latitude': '41.901206994',
#   'dropoff_centroid_longitude': '-87.676355989',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6763559892, 41.9012069941]}},
#  {'trip_id': 'baa00b31fd22a1bac914148b9f4726ae0c9b20d5',
#   'taxi_id': '983ee2eeec397e929937d68bf086a640e2e573f8e701232bd9e16db5a36c53bf5bf031751d3971949c919cfdebd87a6f996321263d4f2d777bcc08800cb41f12',
#   'trip_start_timestamp': '2025-02-23T23:45:00.000',
#   'trip_end_timestamp': '2025-02-24T00:15:00.000',
#   'trip_seconds': '1380',
#   'trip_miles': '16.7',
#   'pickup_census_tract': '17031980000',
#   'pickup_community_area': '76',
#   'fare': '41.25',
#   'tips': '9',
#   'tolls': '0',
#   'extras': '25',
#   'trip_total': '75.25',
#   'payment_type': 'Credit Card',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.97907082',
#   'pickup_centroid_longitude': '-87.903039661',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.9030396611, 41.9790708201]}},
#  {'trip_id': 'badc6bcd9c735bcd8d18fd0905615f2f5559308d',
#   'taxi_id': 'bab73d82a115cb08f1bcd17caebbb2581e3a6f29d92adc859f44304acc357c859fb025673c5b9d6379ab41c191ca7b09fa7275a1ee66bf2e3f55215c1d838430',
#   'trip_start_timestamp': '2025-02-23T23:45:00.000',
#   'trip_end_timestamp': '2025-02-24T00:00:00.000',
#   'trip_seconds': '1320',
#   'trip_miles': '11.3',
#   'pickup_community_area': '56',
#   'fare': '29.75',
#   'tips': '5',
#   'tolls': '0',
#   'extras': '20',
#   'trip_total': '54.75',
#   'payment_type': 'Credit Card',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.79259236',
#   'pickup_centroid_longitude': '-87.769615453',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.7696154528, 41.7925923603]}},
#  {'trip_id': 'bef04870713d5fe723b7b98e0d8f694d423216c3',
#   'taxi_id': 'ae2b1026641fe1802c5c6e0f22f718230861e60d588b0c5356604b0f27ceb519bc34f3f689e6badd3e158149f82e3b7bfc8eaabf23676ebfc42ead87c652a386',
#   'trip_start_timestamp': '2025-02-23T23:45:00.000',
#   'trip_end_timestamp': '2025-02-23T23:45:00.000',
#   'trip_seconds': '303',
#   'trip_miles': '1.86',
#   'pickup_community_area': '3',
#   'dropoff_community_area': '4',
#   'fare': '7.5',
#   'tips': '1.2',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '9.2',
#   'payment_type': 'Mobile',
#   'company': 'Taxicab Insurance Agency Llc',
#   'pickup_centroid_latitude': '41.96581197',
#   'pickup_centroid_longitude': '-87.655878786',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6558787862, 41.96581197]},
#   'dropoff_centroid_latitude': '41.975170943',
#   'dropoff_centroid_longitude': '-87.687515515',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6875155152, 41.9751709433]}},
#  {'trip_id': 'c3da812921cb40931b30327c201f11a83adca7bb',
#   'taxi_id': '13211c2747462616a339ca520978b83ccd7fe5c490b86028f6b478a7d4df9c1cd372bd37c372de3af5754c669827b08b15bdb569f6ce2d82c3ba763780a45815',
#   'trip_start_timestamp': '2025-02-23T23:45:00.000',
#   'trip_end_timestamp': '2025-02-24T00:00:00.000',
#   'trip_seconds': '660',
#   'trip_miles': '3.6',
#   'pickup_community_area': '28',
#   'dropoff_community_area': '8',
#   'fare': '12.5',
#   'tips': '1.88',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '14.38',
#   'payment_type': 'Credit Card',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.874005383',
#   'pickup_centroid_longitude': '-87.66351755',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6635175498, 41.874005383]},
#   'dropoff_centroid_latitude': '41.899602111',
#   'dropoff_centroid_longitude': '-87.633308037',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]}},
#  {'trip_id': 'c6f1b88a9aaa3c6495fa932538522a33ca51044b',
#   'taxi_id': 'f4bc2acfbb68d505b7ca37f8553ab1fc28a2686429b55d0fab2d4d1838e1ffe2316dbf7a4cf417c3e947a62734f6b7dd91f7656ab4f9d5ed13dd8d24a8f87f89',
#   'trip_start_timestamp': '2025-02-23T23:45:00.000',
#   'trip_end_timestamp': '2025-02-24T00:00:00.000',
#   'trip_seconds': '660',
#   'trip_miles': '3.6',
#   'pickup_community_area': '76',
#   'fare': '12',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '16',
#   'payment_type': 'Cash',
#   'company': 'Chicago City Taxi Association',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]}},
#  {'trip_id': 'cf940a964c01a9626f1edddeb52f263d3204d970',
#   'taxi_id': 'ed17822a864c82f0ac8c3110918dacfa804f66b06d9668289cb6d507d300f79adc991ce01dbfcd09b84b1aba420e74a49c5e30ba1e4d03e5966cdc1a225f7991',
#   'trip_start_timestamp': '2025-02-23T23:45:00.000',
#   'trip_end_timestamp': '2025-02-24T00:15:00.000',
#   'trip_seconds': '1588',
#   'trip_miles': '15.08',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '3',
#   'fare': '38.75',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '38.75',
#   'payment_type': 'Cash',
#   'company': 'City Service',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]},
#   'dropoff_centroid_latitude': '41.96581197',
#   'dropoff_centroid_longitude': '-87.655878786',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6558787862, 41.96581197]}},
#  {'trip_id': 'd4ab2e91c7924210aadb922a029d30a88153b971',
#   'taxi_id': '58a80cdb3c9c1a43c90bb9b1d4faa5da222f6b7cf92bc55bd4d0ab6293924f7516091832597425ff50cf147f0f60631bbf079aa4cbd467a437deae0324fbdb9a',
#   'trip_start_timestamp': '2025-02-23T23:45:00.000',
#   'trip_end_timestamp': '2025-02-24T00:00:00.000',
#   'trip_seconds': '686',
#   'trip_miles': '3.81',
#   'pickup_community_area': '28',
#   'dropoff_community_area': '32',
#   'fare': '14.19',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '14.69',
#   'payment_type': 'Mobile',
#   'company': 'Flash Cab',
#   'pickup_centroid_latitude': '41.874005383',
#   'pickup_centroid_longitude': '-87.66351755',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6635175498, 41.874005383]},
#   'dropoff_centroid_latitude': '41.878865584',
#   'dropoff_centroid_longitude': '-87.625192142',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6251921424, 41.8788655841]}},
#  {'trip_id': 'd542c5476182c891d2b93622116ae4062821cb2f',
#   'taxi_id': '0090787181662a792d7a7adbc00cf267181d2d55994971ee4278edb91a8990d3680a598f256abb9fea2f83ed738ff8c3ad6c1bba7844fa60a3c4015e8cef04fb',
#   'trip_start_timestamp': '2025-02-23T23:45:00.000',
#   'trip_end_timestamp': '2025-02-24T00:00:00.000',
#   'trip_seconds': '1380',
#   'trip_miles': '14.5',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '7',
#   'fare': '36.75',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '40.75',
#   'payment_type': 'Cash',
#   'company': '312 Medallion Management Corp',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]},
#   'dropoff_centroid_latitude': '41.922686284',
#   'dropoff_centroid_longitude': '-87.649488729',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6494887289, 41.9226862843]}},
#  {'trip_id': 'd9a5c34abbc9bf749b47a5e4ebc78816ac1bc51e',
#   'taxi_id': '73c53bd1d015d25541aa53570b7f1dd2227cf25b2bed0c08ea9c6099486dd35610416f2bf9937bafe3519b2fbbedd051c719c7b50af95eab8079e03ae86992af',
#   'trip_start_timestamp': '2025-02-23T23:45:00.000',
#   'trip_end_timestamp': '2025-02-24T00:15:00.000',
#   'trip_seconds': '2040',
#   'trip_miles': '17.4',
#   'pickup_community_area': '76',
#   'fare': '43.75',
#   'tips': '21.5',
#   'tolls': '0',
#   'extras': '27.5',
#   'trip_total': '92.75',
#   'payment_type': 'Credit Card',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]}},
#  {'trip_id': 'dcc9fe206d0c5b2a35549ec23aed58a1010ac33c',
#   'taxi_id': '84a9489b354cd6dfe99487c12c5c735e40bb1350f645668ae00ec89cc0c22510a043d8461381406b57db35f51c04f215b889e310c6b151caaa0775504ddc4884',
#   'trip_start_timestamp': '2025-02-23T23:45:00.000',
#   'trip_end_timestamp': '2025-02-24T00:00:00.000',
#   'trip_seconds': '1101',
#   'trip_miles': '12.18',
#   'pickup_census_tract': '17031980100',
#   'dropoff_census_tract': '17031081800',
#   'pickup_community_area': '56',
#   'dropoff_community_area': '8',
#   'fare': '31.5',
#   'tips': '5',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '41',
#   'payment_type': 'Credit Card',
#   'company': 'Chicago Independents',
#   'pickup_centroid_latitude': '41.785998518',
#   'pickup_centroid_longitude': '-87.750934289',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.7509342894, 41.785998518]},
#   'dropoff_centroid_latitude': '41.89321636',
#   'dropoff_centroid_longitude': '-87.63784421',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6378442095, 41.8932163595]}},
#  {'trip_id': 'dfd3df3668885760ed753bf9927b69d9af0bc92c',
#   'taxi_id': 'fca0a8e9246c5f754725d46da0661e884e50559c957ab73fe0e9157b6f52b01b6d400d5af6222646f1681d6f7c30273c573ef9df0b590113016f81b2c5d428c2',
#   'trip_start_timestamp': '2025-02-23T23:45:00.000',
#   'trip_end_timestamp': '2025-02-24T00:00:00.000',
#   'trip_seconds': '567',
#   'trip_miles': '1.72',
#   'pickup_community_area': '56',
#   'fare': '8.25',
#   'tips': '2.75',
#   'tolls': '0',
#   'extras': '5',
#   'trip_total': '16.5',
#   'payment_type': 'Credit Card',
#   'company': 'Taxicab Insurance Agency Llc',
#   'pickup_centroid_latitude': '41.79259236',
#   'pickup_centroid_longitude': '-87.769615453',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.7696154528, 41.7925923603]}},
#  {'trip_id': 'e4441611332c4938006aa28b7ac23ff35655a013',
#   'taxi_id': 'e2d8418fcdb061eee0a4318fba0a6a1200aaff0143feb0a74c7175a02ec7afca09f8c24de278cd0dee124d29dbfb2796407d069b90dfc13353d5d4ed02ecb0d5',
#   'trip_start_timestamp': '2025-02-23T23:45:00.000',
#   'trip_end_timestamp': '2025-02-23T23:45:00.000',
#   'trip_seconds': '249',
#   'trip_miles': '0.54',
#   'pickup_community_area': '8',
#   'dropoff_community_area': '8',
#   'fare': '4.77',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '5.27',
#   'payment_type': 'Mobile',
#   'company': 'Chicago Independents',
#   'pickup_centroid_latitude': '41.899602111',
#   'pickup_centroid_longitude': '-87.633308037',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]},
#   'dropoff_centroid_latitude': '41.899602111',
#   'dropoff_centroid_longitude': '-87.633308037',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]}},
#  {'trip_id': 'e4eed9802c0014566d566a152a1c9f2152ad9c44',
#   'taxi_id': 'd6fd39863cdce99011c7282605bedf70d9d059ecf0da5e93242f3de6c55f79b8dfe37a4f5fbc09e022d9a1e7c5be50360aa1852d04f9e42695742191ccb25606',
#   'trip_start_timestamp': '2025-02-23T23:45:00.000',
#   'trip_end_timestamp': '2025-02-24T00:15:00.000',
#   'trip_seconds': '1237',
#   'trip_miles': '15.3',
#   'pickup_community_area': '76',
#   'fare': '38',
#   'tips': '13.5',
#   'tolls': '0',
#   'extras': '29',
#   'trip_total': '81',
#   'payment_type': 'Credit Card',
#   'company': 'Choice Taxi Association Inc',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]}},
#  {'trip_id': 'e69a185559cece7db0dd206e38f1bd64eaaf5d89',
#   'taxi_id': '32693393c16a975b5a11cddc63ad4e963b8b3282ba08b2dd73658686ea8ae039714ddc97656cbccc825f27de142f37a796e0859c5b0ddd5ffd242ac92a0a5e15',
#   'trip_start_timestamp': '2025-02-23T23:45:00.000',
#   'trip_end_timestamp': '2025-02-23T23:45:00.000',
#   'trip_seconds': '7',
#   'trip_miles': '0',
#   'pickup_census_tract': '17031770202',
#   'dropoff_census_tract': '17031770202',
#   'fare': '145',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '145',
#   'payment_type': 'Cash',
#   'company': '5 Star Taxi'},
#  {'trip_id': 'f3221b8ac887266c8f971b52f045a72aba93e07a',
#   'taxi_id': '60bfa66fda3ce439a0ca18ec81dccc1b094f5c9734786820539411ad8435cab126447d87a051942bc5f96d16209ef2b3077aef3341ef2ac0a1276cecf41522d1',
#   'trip_start_timestamp': '2025-02-23T23:45:00.000',
#   'trip_end_timestamp': '2025-02-24T00:15:00.000',
#   'trip_seconds': '1200',
#   'trip_miles': '17.6',
#   'pickup_census_tract': '17031980000',
#   'dropoff_census_tract': '17031839100',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '32',
#   'fare': '43',
#   'tips': '12.4',
#   'tolls': '0',
#   'extras': '18.5',
#   'trip_total': '73.9',
#   'payment_type': 'Credit Card',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.97907082',
#   'pickup_centroid_longitude': '-87.903039661',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.9030396611, 41.9790708201]},
#   'dropoff_centroid_latitude': '41.880994471',
#   'dropoff_centroid_longitude': '-87.632746489',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6327464887, 41.8809944707]}},
#  {'trip_id': 'fbff02aaefc95947940849a818a5086448546df6',
#   'taxi_id': '9fb94ceaab8c4ba0476f7dce462b8965841f7848dfb81dfd7cb6ced50f86fcd1e58d39f20ee259740144be330b083e76d26508d768ce02f07e484a9c867b9b49',
#   'trip_start_timestamp': '2025-02-23T23:45:00.000',
#   'trip_end_timestamp': '2025-02-24T00:15:00.000',
#   'trip_seconds': '1636',
#   'trip_miles': '14.12',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '6',
#   'fare': '36.75',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '40.75',
#   'payment_type': 'Cash',
#   'company': 'Medallion Leasin',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]},
#   'dropoff_centroid_latitude': '41.944226601',
#   'dropoff_centroid_longitude': '-87.655998182',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6559981815, 41.9442266014]}},
#  {'trip_id': '1aa29744024c89ce3ad93a057c51bd114ee9b508',
#   'taxi_id': '6db76715006643fd2c01bce95f1ccb0e4898c982bdd49e41f8ec43fddf585f125f2a9702ae605ba0540e02283565acb9c86a9615090f995257c7f6b41b39d925',
#   'trip_start_timestamp': '2025-02-23T23:45:00.000',
#   'trip_end_timestamp': '2025-02-24T00:15:00.000',
#   'trip_seconds': '2212',
#   'trip_miles': '13.41',
#   'pickup_community_area': '24',
#   'dropoff_community_area': '69',
#   'fare': '37',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '37',
#   'payment_type': 'Prcard',
#   'company': 'Medallion Leasin',
#   'pickup_centroid_latitude': '41.901206994',
#   'pickup_centroid_longitude': '-87.676355989',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6763559892, 41.9012069941]},
#   'dropoff_centroid_latitude': '41.763246799',
#   'dropoff_centroid_longitude': '-87.616134111',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6161341112, 41.7632467988]}},
#  {'trip_id': '1e439a7d0f3e69be442094e6e31d55b5d6013bbe',
#   'taxi_id': '10e8a565ac8829bd9caa44f57e9831fd8b4ff374e4d6667337dc4114eb4a0356ec563e55a82e248e315ebf8e938ed4c8418dda95d5a5b409e7ce9b6139215b24',
#   'trip_start_timestamp': '2025-02-23T23:45:00.000',
#   'trip_end_timestamp': '2025-02-23T23:45:00.000',
#   'trip_seconds': '285',
#   'trip_miles': '1.23',
#   'pickup_community_area': '8',
#   'dropoff_community_area': '8',
#   'fare': '6.25',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '6.25',
#   'payment_type': 'Cash',
#   'company': 'Flash Cab',
#   'pickup_centroid_latitude': '41.899602111',
#   'pickup_centroid_longitude': '-87.633308037',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]},
#   'dropoff_centroid_latitude': '41.899602111',
#   'dropoff_centroid_longitude': '-87.633308037',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]}},
#  {'trip_id': '195e8deb10594a231a8c53ede40e5cb9756dc994',
#   'taxi_id': '1d68f4a1c3b620f920838643bf3801e757b6791f86700abce6ca5936659e046f715635d4bda0aadcedb6df46949cf9d74003f214779efdd04138bd36adf5d9c9',
#   'trip_start_timestamp': '2025-02-23T23:45:00.000',
#   'trip_end_timestamp': '2025-02-24T00:00:00.000',
#   'trip_seconds': '1353',
#   'trip_miles': '20.61',
#   'pickup_census_tract': '17031980000',
#   'pickup_community_area': '76',
#   'fare': '50',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '25',
#   'trip_total': '75',
#   'payment_type': 'Cash',
#   'company': 'Sun Taxi',
#   'pickup_centroid_latitude': '41.97907082',
#   'pickup_centroid_longitude': '-87.903039661',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.9030396611, 41.9790708201]}},
#  {'trip_id': '225eafa7e5d2ee7597bb0bd051d89aa3dcfe2cf6',
#   'taxi_id': '7ec17a8416dca01eef674860959ae50b91aeecb1b417b0fd7581851cf7e8a3e84d61f95d616b364ddeb9c0a9bb44b160c5b9319390d85c16552fbc2a513dca78',
#   'trip_start_timestamp': '2025-02-23T23:45:00.000',
#   'trip_end_timestamp': '2025-02-24T00:15:00.000',
#   'trip_seconds': '1930',
#   'trip_miles': '17',
#   'pickup_census_tract': '17031980000',
#   'dropoff_census_tract': '17031839100',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '32',
#   'fare': '45.75',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '50.25',
#   'payment_type': 'Credit Card',
#   'company': 'Taxicab Insurance Agency Llc',
#   'pickup_centroid_latitude': '41.97907082',
#   'pickup_centroid_longitude': '-87.903039661',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.9030396611, 41.9790708201]},
#   'dropoff_centroid_latitude': '41.880994471',
#   'dropoff_centroid_longitude': '-87.632746489',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6327464887, 41.8809944707]}},
#  {'trip_id': '23ccfa495fbac1551061375b1a5ea8558a0060a2',
#   'taxi_id': '3d90e25b8ab0de4b8255efb250b64017386e76574210ea6c2d3f6d276362d17ae3544a96b78fc891c7904907bbe8396995619d714b1e5309016079c938909f9f',
#   'trip_start_timestamp': '2025-02-23T23:45:00.000',
#   'trip_end_timestamp': '2025-02-24T00:15:00.000',
#   'trip_seconds': '1214',
#   'trip_miles': '12.08',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '5',
#   'fare': '31.25',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '5',
#   'trip_total': '36.25',
#   'payment_type': 'Cash',
#   'company': 'Flash Cab',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]},
#   'dropoff_centroid_latitude': '41.947791586',
#   'dropoff_centroid_longitude': '-87.683834942',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6838349425, 41.9477915865]}},
#  {'trip_id': '23e4c5c4fea0902ac5a90abeb2dc681d4d00c303',
#   'taxi_id': 'ac1f0defd00d6b7417e39256ebe1cad16b64955f9a64f2eaecee6f54e52ec118133f687c8b6603d6e9a27d86a8921fc30e1458e804686d05f9cb83751fac3382',
#   'trip_start_timestamp': '2025-02-23T23:45:00.000',
#   'trip_end_timestamp': '2025-02-24T00:15:00.000',
#   'trip_seconds': '1157',
#   'trip_miles': '11.9',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '5',
#   'fare': '30.75',
#   'tips': '7.25',
#   'tolls': '0',
#   'extras': '5',
#   'trip_total': '43.5',
#   'payment_type': 'Credit Card',
#   'company': 'City Service',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]},
#   'dropoff_centroid_latitude': '41.947791586',
#   'dropoff_centroid_longitude': '-87.683834942',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6838349425, 41.9477915865]}},
#  {'trip_id': '2532304741ffbc667d5b00dbe1f33c12b9917e80',
#   'taxi_id': '2e82e26afb77e809fe4a44b02a152bdc079623600ae1b767fa44969c1fecedae23b48b65a2e48b8d9e602673db6c2be9ce16f233c3391100efa4c11bd562dbad',
#   'trip_start_timestamp': '2025-02-23T23:45:00.000',
#   'trip_end_timestamp': '2025-02-24T00:00:00.000',
#   'trip_seconds': '1560',
#   'trip_miles': '15',
#   'pickup_community_area': '56',
#   'dropoff_community_area': '6',
#   'fare': '37.75',
#   'tips': '7',
#   'tolls': '0',
#   'extras': '5',
#   'trip_total': '49.75',
#   'payment_type': 'Credit Card',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.79259236',
#   'pickup_centroid_longitude': '-87.769615453',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.7696154528, 41.7925923603]},
#   'dropoff_centroid_latitude': '41.944226601',
#   'dropoff_centroid_longitude': '-87.655998182',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6559981815, 41.9442266014]}},
#  {'trip_id': '26ea3aab44447792e2b338c9a8156a9a3b954eaf',
# ...
#   'payment_type': 'Cash',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.79259236',
#   'pickup_centroid_longitude': '-87.769615453',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.7696154528, 41.7925923603]},
#   'dropoff_centroid_latitude': '41.878865584',
#   'dropoff_centroid_longitude': '-87.625192142',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6251921424, 41.8788655841]}},
#  {'trip_id': '58033a20bf1b9737b7f45589b3dffbd2ef91e94e',
#   'taxi_id': '502a000e4ee99c96dc9964f2994671b57b73fd6902e2342ce2c0a2964ccac777078c7f455e928fecd64cc01571af88a107fc0341b5a5b8cf2d5f06212d972cd9',
#   'trip_start_timestamp': '2025-02-23T21:15:00.000',
#   'trip_end_timestamp': '2025-02-23T21:45:00.000',
#   'trip_seconds': '1804',
#   'trip_miles': '13.43',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '5',
#   'fare': '35.75',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '35.75',
#   'payment_type': 'Cash',
#   'company': '5 Star Taxi',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]},
#   'dropoff_centroid_latitude': '41.947791586',
#   'dropoff_centroid_longitude': '-87.683834942',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6838349425, 41.9477915865]}},
#  {'trip_id': '54832d37d5226d04788a614b7c79cab28fcf8128',
#   'taxi_id': '16a233f62883c48f7462a0d5b87191190c49a46fe52f37aa0c5949a00e347ef3c1fdb324e6edd288d3d161ecb637ed4728732312b8b12f104432caff782c11e9',
#   'trip_start_timestamp': '2025-02-23T21:15:00.000',
#   'trip_end_timestamp': '2025-02-23T21:30:00.000',
#   'trip_seconds': '1029',
#   'trip_miles': '12.43',
#   'pickup_community_area': '44',
#   'dropoff_community_area': '8',
#   'fare': '31.75',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '31.75',
#   'payment_type': 'Prcard',
#   'company': 'Flash Cab',
#   'pickup_centroid_latitude': '41.740205756',
#   'pickup_centroid_longitude': '-87.615969523',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6159695226, 41.7402057565]},
#   'dropoff_centroid_latitude': '41.899602111',
#   'dropoff_centroid_longitude': '-87.633308037',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]}},
#  {'trip_id': '4f7dcd126a362bb9343cb3e93fd177bcf6352c5b',
#   'taxi_id': '179f1a051e9e6d3fc0726628962faff68506086ee8df14091e91399452fada055453e421df026fcc4449a43ba54a357c364482e62a20420f836389bd2269b5ee',
#   'trip_start_timestamp': '2025-02-23T21:15:00.000',
#   'trip_end_timestamp': '2025-02-23T21:45:00.000',
#   'trip_seconds': '1304',
#   'trip_miles': '9.38',
#   'pickup_community_area': '76',
#   'fare': '26',
#   'tips': '6.1',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '36.6',
#   'payment_type': 'Credit Card',
#   'company': 'Blue Ribbon Taxi Association',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]}},
#  {'trip_id': '4aafc4e5e4cd1127fdbd27dc9ef113b504a1f77c',
#   'taxi_id': 'de8e8659ceb9eb0da842a46b60c0a5207098ac69fc23ab1d6308a50a42e719c1b9d233d3b57a3591ee5789f9cc7e22e81496194980774e8035033e0788ec2633',
#   'trip_start_timestamp': '2025-02-23T21:15:00.000',
#   'trip_end_timestamp': '2025-02-23T21:45:00.000',
#   'trip_seconds': '2149',
#   'trip_miles': '29.66',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '70',
#   'fare': '70.5',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '9.5',
#   'trip_total': '80',
#   'payment_type': 'Cash',
#   'company': 'Sun Taxi',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]},
#   'dropoff_centroid_latitude': '41.745757713',
#   'dropoff_centroid_longitude': '-87.708365704',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.7083657043, 41.7457577128]}},
#  {'trip_id': '471e5c8899cb787979a6c2d8eb24f689031d5ec5',
#   'taxi_id': '5c34774d7f085ba650e743a8c07f3f9d5c78a19102b22fedfc6b1781c49e3300b6a7bb35a1f4fa87738713a590d8bd6cda2496bf224ca023935ab0e3759935b9',
#   'trip_start_timestamp': '2025-02-23T21:15:00.000',
#   'trip_end_timestamp': '2025-02-23T21:45:00.000',
#   'trip_seconds': '2086',
#   'trip_miles': '26.11',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '41',
#   'fare': '62.75',
#   'tips': '17.06',
#   'tolls': '0',
#   'extras': '5',
#   'trip_total': '85.31',
#   'payment_type': 'Credit Card',
#   'company': 'Sun Taxi',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]},
#   'dropoff_centroid_latitude': '41.794090253',
#   'dropoff_centroid_longitude': '-87.592310855',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.592310855, 41.794090253]}},
#  {'trip_id': '46059c67304b194a04c7684bbfd72380fa447b97',
#   'taxi_id': '4df6b6047a892dbaa59a3950e23072959d80fb44bf918ba9359e4283235a5909e5292e5e9a41ecdcdfdcacf7a17db67db50a61054c14aa0c4fa4ccaf7fbc8b9a',
#   'trip_start_timestamp': '2025-02-23T21:15:00.000',
#   'trip_end_timestamp': '2025-02-23T21:15:00.000',
#   'trip_seconds': '19',
#   'trip_miles': '0',
#   'pickup_community_area': '28',
#   'dropoff_community_area': '28',
#   'fare': '9.97',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '10.47',
#   'payment_type': 'Mobile',
#   'company': 'Medallion Leasin',
#   'pickup_centroid_latitude': '41.874005383',
#   'pickup_centroid_longitude': '-87.66351755',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6635175498, 41.874005383]},
#   'dropoff_centroid_latitude': '41.874005383',
#   'dropoff_centroid_longitude': '-87.66351755',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6635175498, 41.874005383]}},
#  {'trip_id': '45c1f9982827134a48487b2719bac0685c68c0b8',
#   'taxi_id': 'ad4e285cc063909f5c4550bbc3b71f1c6672b9967c486814da5b11721045f4dce8c8913b56084ab8995010c13e1132fabe15fce55d81605996636828a84d2ddb',
#   'trip_start_timestamp': '2025-02-23T21:15:00.000',
#   'trip_end_timestamp': '2025-02-23T21:30:00.000',
#   'trip_seconds': '1559',
#   'trip_miles': '17.69',
#   'pickup_census_tract': '17031980000',
#   'dropoff_census_tract': '17031320400',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '32',
#   'fare': '44',
#   'tips': '9.7',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '58.2',
#   'payment_type': 'Credit Card',
#   'company': 'Taxicab Insurance Agency Llc',
#   'pickup_centroid_latitude': '41.97907082',
#   'pickup_centroid_longitude': '-87.903039661',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.9030396611, 41.9790708201]},
#   'dropoff_centroid_latitude': '41.877406123',
#   'dropoff_centroid_longitude': '-87.621971652',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6219716519, 41.8774061234]}},
#  {'trip_id': '452f7ce360255397c974b00f6d1a25e7ffd4c98e',
#   'taxi_id': '07f3ce687dce8fa4518b83cd63bfbfb0383339fd188b5b6b22f4d33d0dbc445b56eabe1b74a1e06ab4cd5533bfdb89f0322934d5a2cc4fa67a4eb383ffd743ec',
#   'trip_start_timestamp': '2025-02-23T21:15:00.000',
#   'trip_end_timestamp': '2025-02-23T21:30:00.000',
#   'trip_seconds': '1020',
#   'trip_miles': '12.5',
#   'pickup_community_area': '44',
#   'dropoff_community_area': '39',
#   'fare': '31.5',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '31.5',
#   'payment_type': 'Unknown',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.740205756',
#   'pickup_centroid_longitude': '-87.615969523',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6159695226, 41.7402057565]},
#   'dropoff_centroid_latitude': '41.808916283',
#   'dropoff_centroid_longitude': '-87.596183344',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.5961833442, 41.8089162826]}},
#  {'trip_id': '42b6bb58a6dc1b4c86185bd100c9bbdb260085f5',
#   'taxi_id': '7e7c8866e9fc3cc3993f99301a61766a02088a197334db1f4d7a0ed952a59e6f6888b8c7a38786cbcaac98124bdc64dd5604cb1208bd5004527c539b7f6d1230',
#   'trip_start_timestamp': '2025-02-23T21:15:00.000',
#   'trip_end_timestamp': '2025-02-23T21:30:00.000',
#   'trip_seconds': '1680',
#   'trip_miles': '17.5',
#   'pickup_census_tract': '17031980000',
#   'dropoff_census_tract': '17031081403',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '8',
#   'fare': '43.5',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '47.5',
#   'payment_type': 'Cash',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.97907082',
#   'pickup_centroid_longitude': '-87.903039661',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.9030396611, 41.9790708201]},
#   'dropoff_centroid_latitude': '41.890922026',
#   'dropoff_centroid_longitude': '-87.618868355',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6188683546, 41.8909220259]}},
#  {'trip_id': '3f003772876ba3e3646d7be1e56c1ffaaad50aa4',
#   'taxi_id': 'b2b3941b38fad492b956dc4ec546dab16697d7071bcb02e32dc134d60ff07af848f7cc28394204910ec2e442df14f07c7c48828f1d8a317f9365e8f394ac4a8b',
#   'trip_start_timestamp': '2025-02-23T21:15:00.000',
#   'trip_end_timestamp': '2025-02-23T21:30:00.000',
#   'trip_seconds': '1260',
#   'trip_miles': '16.8',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '28',
#   'fare': '41.25',
#   'tips': '10',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '55.25',
#   'payment_type': 'Credit Card',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]},
#   'dropoff_centroid_latitude': '41.874005383',
#   'dropoff_centroid_longitude': '-87.66351755',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6635175498, 41.874005383]}},
#  {'trip_id': '3e58a52f113fa85a6a9d3457962ff3784edb14c6',
#   'taxi_id': '249d932165de24c10140f979fa81b350183cff7ac630991ebc0e2b567883a3c60780ed9dd4f087f74022f6af1eb04d11f888b84b182f90a5e1996bc87da1fa70',
#   'trip_start_timestamp': '2025-02-23T21:15:00.000',
#   'trip_end_timestamp': '2025-02-23T21:45:00.000',
#   'trip_seconds': '1591',
#   'trip_miles': '18.22',
#   'pickup_census_tract': '17031980000',
#   'dropoff_census_tract': '17031081403',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '8',
#   'fare': '45.25',
#   'tips': '5',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '50.75',
#   'payment_type': 'Mobile',
#   'company': 'Globe Taxi',
#   'pickup_centroid_latitude': '41.97907082',
#   'pickup_centroid_longitude': '-87.903039661',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.9030396611, 41.9790708201]},
#   'dropoff_centroid_latitude': '41.890922026',
#   'dropoff_centroid_longitude': '-87.618868355',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6188683546, 41.8909220259]}},
#  {'trip_id': '3d0768bdaa4a3b91180c4fce7d070b7cd89cca09',
#   'taxi_id': '8dbaf4164524af926ddeab5dd084183e585f4cb8cc47febbd2839986312079990fae419bfaa5d557574992d87939d1842f1c86812c8678bb3806af6fe227d755',
#   'trip_start_timestamp': '2025-02-23T21:15:00.000',
#   'trip_end_timestamp': '2025-02-23T21:45:00.000',
#   'trip_seconds': '1384',
#   'trip_miles': '17.66',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '8',
#   'fare': '43.25',
#   'tips': '9.75',
#   'tolls': '0',
#   'extras': '5',
#   'trip_total': '58.5',
#   'payment_type': 'Credit Card',
#   'company': 'Medallion Leasin',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]},
#   'dropoff_centroid_latitude': '41.899602111',
#   'dropoff_centroid_longitude': '-87.633308037',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]}},
#  {'trip_id': '3ad6c0144acccec3619cd575da15a44b48f9cc8a',
#   'taxi_id': '95e2243f1be3ddd4b546741f6176fb12f2101fdc321377deb6a90915750c19d388915c3ee42dd04060b56e139f57dee79553cf85c71424715337145addae5fde',
#   'trip_start_timestamp': '2025-02-23T21:15:00.000',
#   'trip_end_timestamp': '2025-02-23T21:15:00.000',
#   'trip_seconds': '600',
#   'trip_miles': '3.5',
#   'pickup_community_area': '32',
#   'dropoff_community_area': '24',
#   'fare': '11.75',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '11.75',
#   'payment_type': 'Cash',
#   'company': '312 Medallion Management Corp',
#   'pickup_centroid_latitude': '41.878865584',
#   'pickup_centroid_longitude': '-87.625192142',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6251921424, 41.8788655841]},
#   'dropoff_centroid_latitude': '41.901206994',
#   'dropoff_centroid_longitude': '-87.676355989',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6763559892, 41.9012069941]}},
#  {'trip_id': '36c368a5a2127b1a6a10f3954fa5c4f5b8a23202',
#   'taxi_id': 'ae31f2151e8b85c5c1981e09c227aa451a6fda9b739d6331d7edb934d6fc6419440b1fab1648164c4c814fdfb4dc04ab2b871230f2d2ab5cf880ae5203fd20c3',
#   'trip_start_timestamp': '2025-02-23T21:15:00.000',
#   'trip_end_timestamp': '2025-02-23T21:15:00.000',
#   'trip_seconds': '529',
#   'trip_miles': '3.93',
#   'pickup_community_area': '3',
#   'dropoff_community_area': '8',
#   'fare': '12.15',
#   'tips': '3.09',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '15.74',
#   'payment_type': 'Mobile',
#   'company': 'Blue Ribbon Taxi Association',
#   'pickup_centroid_latitude': '41.96581197',
#   'pickup_centroid_longitude': '-87.655878786',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6558787862, 41.96581197]},
#   'dropoff_centroid_latitude': '41.899602111',
#   'dropoff_centroid_longitude': '-87.633308037',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]}},
#  {'trip_id': '3637ff96c668549a92f6bbd2d680a0cacb028cff',
#   'taxi_id': 'cb8da8dde1057540d8da485b4510d133316163e21fbef92f4d46f219459930016ec548fae8987cda4130590ceccdfab888567bcc1b861922d125a15aa899a1e9',
#   'trip_start_timestamp': '2025-02-23T21:15:00.000',
#   'trip_end_timestamp': '2025-02-23T22:00:00.000',
#   'trip_seconds': '2082',
#   'trip_miles': '20.43',
#   'pickup_community_area': '56',
#   'dropoff_community_area': '77',
#   'fare': '50.5',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '5',
#   'trip_total': '55.5',
#   'payment_type': 'Cash',
#   'company': 'Flash Cab',
#   'pickup_centroid_latitude': '41.79259236',
#   'pickup_centroid_longitude': '-87.769615453',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.7696154528, 41.7925923603]},
#   'dropoff_centroid_latitude': '41.9867118',
#   'dropoff_centroid_longitude': '-87.663416405',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6634164054, 41.9867117999]}},
#  {'trip_id': '3498996d5486412eb8cc370aaec13a813ec25e0f',
#   'taxi_id': 'a500c0da8fa893c9bdff48770ab8acfcb8d874014a09a9bfbff7f3e682919e522adb81b4d4036f38f7fd9b6475d1bfe50c0ec5d1805bc67d21281e800073adcf',
#   'trip_start_timestamp': '2025-02-23T21:15:00.000',
#   'trip_end_timestamp': '2025-02-23T21:45:00.000',
#   'trip_seconds': '1740',
#   'trip_miles': '10.1',
#   'pickup_community_area': '8',
#   'dropoff_community_area': '15',
#   'fare': '28.75',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '28.75',
#   'payment_type': 'No Charge',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.899602111',
#   'pickup_centroid_longitude': '-87.633308037',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]},
#   'dropoff_centroid_latitude': '41.954027649',
#   'dropoff_centroid_longitude': '-87.763399032',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.7633990316, 41.9540276487]}},
#  ...]

# %%
# Formulate this as a standalone function
from typing import Dict
def get_taxi_data(formatted_datetime: str) -> Dict:
    """Build API URL, send request and parse response
    for taxi_data  
    Args:
        formatted_datetime (str):
        Date to retrieve taxi_data in a string like '2025-02-20'
    Returns:
        Dict:
        Response JSOn content
    """
    taxi_url = (
        f"https://data.cityofchicago.org/resource/ajtu-isnz.json?"
        f"$where=trip_start_timestamp >= '{formatted_datetime}T00:00:00' "
        f"AND trip_start_timestamp <= '{formatted_datetime}T23:59:59'&$limit=30000"
    )
    response = requests.get(taxi_url)
    taxi_data = response.json()
    return taxi_data
